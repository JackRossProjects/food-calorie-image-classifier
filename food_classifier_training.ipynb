# %% [markdown]
# #Creating our own dataset using Google Images
# In this notebook we are creating our own dataset of teddy bear, black bear and grizzly bear and try to classify between them.We are going to use following javascript code to download the images from Google Images.
#
# **javascript code**:
#
# urls = Array.from(document.querySelectorAll('.rg_di .rg_meta')).map(el=>JSON.parse(el.textContent).ou);
#
# window.open('data:text/csv;charset=utf-8,' + escape(urls.join('\n')));

# %%
#importing the drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Colab library to upload files to notebook
from google.colab import files

# Install Kaggle library
# !pip install -q kaggle

# %%
# Upload kaggle API key file
uploaded = files.upload()
# Out:
#      <input type="file" id="files-26bad7e8-fc6a-4668-baa6-a0d08f570135" name="files[]" multiple disabled />
#      <output id="result-26bad7e8-fc6a-4668-baa6-a0d08f570135">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle (1).json to kaggle (1) (1).json

# %%
# !kaggle datasets download -d kmader/food41
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/kaggle", line 5, in <module>
#     from kaggle.cli import main
#   File "/usr/local/lib/python2.7/dist-packages/kaggle/__init__.py", line 23, in <module>
#     api.authenticate()
#   File "/usr/local/lib/python2.7/dist-packages/kaggle/api/kaggle_api_extended.py", line 146, in authenticate
#     self.config_file, self.config_dir))
# IOError: Could not find kaggle.json. Make sure it's located in /root/.kaggle. Or use the environment method.

# %%
#importing the required packages
from fastai.vision import *
from fastai.metrics import error_rate

# %%
cd drive/My\ Drive
# Out:
# /content/drive/My Drive

# %%
#creating directory
path = Path('/content/')

dest = path/'apple_pie'
dest.mkdir(parents = True, exist_ok = True)

dest = path/'baby_back_ribs'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'baklava'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'beef_carpaccio'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'beef_tartare'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'beet_salad'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'beignets'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'bibimbap'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'bread_pudding'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'breakfast_burrito'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'bruschetta'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'caesar_salad'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'cannoli'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'caprese_salad'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'carrot_cake'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'ceviche'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'cheesecake'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'cheese_plate'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'chicken_curry'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'chicken_quesadilla'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'chicken_wings'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'chocolate_cake'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'chocolate_mousse'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'churros'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'clam_chowder'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'club_sandwhich'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'crab_cakes'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'creme_brulee'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'croque_madame'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'cup_cakes'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'deviled_eggs'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'donuts'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'dumplings'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'endemame'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'eggs_benedict'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'escargots'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'falafel'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'filet_mignon'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'fish_and_chips'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'foie_gras'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'french_fries'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'french_onion_soup'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'french_toast'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'fried_calamari'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'fried_rice'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'frozen_yogurt'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'garlic_bread'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'gnocchi'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'greek_salad'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'grilled_cheese_sandwhich'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'grilled_salmon'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'guacamole'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'gyoza'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'hamburger'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'hot_and_sour_soup'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'hot_dog'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'huevos_rancheros'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'hummus'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'ice_cream'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'lasagna'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'lobster_bisque'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'lobster_roll_sandwhich'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'macaroni_and_cheese'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'macarons'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'miso_soup'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'mussels'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'nachos'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'omelette'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'onion_rings'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'oysters'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'pad_thai'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'paella'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'pancakes'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'panna_cotta'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'peking_duck'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'pho'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'pizza'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'pork_chop'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'poutine'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'prime_rib'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'pulled_pork_sandwich'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'ramen'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'ravioli'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'red_velvet_cake'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'risotto'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'samosa'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'sashimi'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'scallops'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'seaweed_salad'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'shrimp_and_grits'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'spaghetti_bolognese'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'spaghetti_carbonara'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'spring_rolls'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'steak'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'strawberry_shortcake'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'sushi'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'tacos'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'takoyaki'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'tiramisu'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'tuna_tartare'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'waffles'
dest.mkdir(parents=True, exist_ok=True)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#deleting corrupted images

classes = ['apple_pie','baby_back_ribs','baklava', 'beef_carpaccio', 
           'beef_tartare', 'beet_salad', 'beignets', 'bibimbap',
           'bread_pudding', 'breakfast_burrito', 'bruschetta',
           'caesar_salad', 'cannoli', 'caprese_salad', 'carrot_cake', 
           'ceviche', 'cheesecake', 'cheese_plate', 'chicken_curry', 
           'chicken_quesadilla', 'chicken_wings', 'chocolate_cake', 
           'chocolate_mousse', 'churros', 'clam_chowder', 'club_sandwich', 
           'crab_cakes', 'creme_brulee', 'croque_madame', 'cup_cakes', 
           'deviled_eggs', 'donuts', 'dumplings', 'edamame', 'eggs_benedict', 
           'escargots', 'falafel', 'filet_mignon', 'fish_and_chips', 
           'foie_gras', 'french_fries', 'french_onion_soup', 
           'french_toast', 'fried_calamari', 'fried_rice', 'frozen_yogurt', 
           'garlic_bread', 'gnocchi', 'greek_salad', 'grilled_cheese_sandwich', 
           'grilled_salmon', 'guacamole', 'gyoza', 'hamburger', 
           'hot_and_sour_soup', 'hot_dog', 'huevos_rancheros', 'hummus', 
           'ice_cream', 'lasagna', 'lobster_bisque', 'lobster_roll_sandwich', 
           'macaroni_and_cheese', 'macarons', 'miso_soup', 'mussels', 
           'nachos', 'omelette', 'onion_rings', 'oysters', 'pad_thai', 
           'paella', 'pancakes', 'panna_cotta', 'peking_ducks', 
           'pho', 'pizza', 'pork_chop', 'poutine', 'prime_rib', 
           'pulled_pork_sandwich', 'ramen', 'ravioli', 'red_velvet_cake', 
           'risotto', 'samosa', 'sashimi', 'scallops', 'seaweed_salad', 
           'shrimp_and_grits', 'spaghetti_bolognese', 'spaghetti_carbonara', 
           'spring_rolls', 'steak', 'strawberry_shortcake', 'sushi', 
           'tacos', 'takoyako', 'tiramisu', 'tuna_tartare', 'waffles']

for c in classes:
  print(c)
  verify_images(path/c, delete = True, max_size = 500)

# %%
#view data
data = ImageDataBunch.from_folder(path, train='.', valid_pct = 0.2, seed=66,
                                  ds_tfms = get_transforms(), size = 224).normalize(imagenet_stats)
data.show_batch(rows = 10, figsize = (10,10))

# %%
print(data.classes)
print(len(data.train_ds))
print(len(data.valid_ds))
# Out:
# ['apple_pie', 'baby_back_ribs', 'baklava', 'beef_carpaccio', 'beef_tartare', 'beet_salad', 'beignets', 'bibimbap', 'bread_pudding', 'breakfast_burrito', 'bruschetta', 'caesar_salad', 'cannoli', 'caprese_salad', 'carrot_cake', 'ceviche', 'cheese_plate', 'cheesecake', 'chicken_curry', 'chicken_quesadilla', 'chicken_wings', 'chocolate_cake', 'chocolate_mousse', 'churros', 'clam_chowder', 'club_sandwich', 'crab_cakes', 'creme_brulee', 'croque_madame', 'cup_cakes', 'deviled_eggs', 'donuts', 'dumplings', 'edamame', 'eggs_benedict', 'escargots', 'falafel', 'filet_mignon', 'fish_and_chips', 'foie_gras', 'french_fries', 'french_onion_soup', 'french_toast', 'fried_calamari', 'fried_rice', 'frozen_yogurt', 'garlic_bread', 'gnocchi', 'greek_salad', 'grilled_cheese_sandwich', 'grilled_salmon', 'guacamole', 'gyoza', 'hamburger', 'hot_and_sour_soup', 'hot_dog', 'huevos_rancheros', 'hummus', 'ice_cream', 'lasagna', 'lobster_bisque', 'lobster_roll_sandwich', 'macaroni_and_cheese', 'macarons', 'miso_s
# ...

# %% [markdown]
# #Training

# %%
learn = cnn_learner(data, models.resnet34, metrics = error_rate)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.cache/torch/checkpoints/resnet34-333f7ec4.pth
# 100%|██████████| 83.3M/83.3M [00:02<00:00, 36.0MB/s]

# %%
learn.fit_one_cycle(12)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='6' class='' max='12', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       50.00% [6/12 6:55:26<6:55:26]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
# ...

# %%
learn.recorder.plot_losses()

# %%
learn.save('stage-1')

# %%
learn.unfreeze()

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.fit_one_cycle(3,max_lr=slice(3e-5,3e-4))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.347660</td>
#       <td>0.507767</td>
#       <td>0.132665</td>
#       <td>04:21</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.271901</td>
#       <td>0.402720</td>
#       <td>0.111454</td>
#       <td>04:19</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.146705</td>
#       <td>0.370793</td>
#       <td>0.099499</td>
#       <td>04:29</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# This doesn't help much so we use the stage-1 training.

# %%
learn.save('stage-2')

# %% [markdown]
# #Interpretation

# %%
learn.load('stage-1');

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_confusion_matrix()

# %%
interp.plot_top_losses(k = 4, heatmap=False)

# %% [markdown]
# #Prediction

# %%
defaults.device = torch.device('cpu')

# %%
learn.export()

# %%
#example image
img = open_image(path/'baklava/104446.jpg')
img
# Out:
# Image (3, 373, 500)

# %%
learn = load_learner(path)

# %%
pred,idx,outputs = learn.predict(img)
print('Predicted class: ',pred)
# Out:
# Predicted class:  baklava

# %%
img = open_image(path/'baby_back_ribs/108211.jpg')
img
# Out:
# Image (3, 375, 500)

# %%
pred,idx,outputs = learn.predict(img)
print('Prediction: ',pred)
# Out:
# Prediction:  baby_back_ribs

# %%
learn = cnn_learner(data, models.resnet18)
